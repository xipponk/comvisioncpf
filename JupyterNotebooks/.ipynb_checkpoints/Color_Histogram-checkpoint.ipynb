# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

path = r'../images/beach.png'
image = cv2.imread(path)

cv2.startWindowThread()
cv2.imshow("Original", image)

chans = cv2.split(image)
colors = ('b', 'g', 'r')

fig, ax = plt.subplots(3, 1, figsize=(5, 10))
fig.tight_layout(pad=3)
ax[0].set(title='Blue Histogram', xlabel='Bins', ylabel='# of Pixels', xlim=[0, 256]);
ax[1].set(title='Green Histogram', xlabel='Bins', ylabel='# of Pixels', xlim=[0, 256]);
ax[2].set(title='Red Histogram', xlabel='Bins', ylabel='# of Pixels', xlim=[0, 256]);

'''
plt.figure()
plt.title('Flattened Color Histogram')
plt.xlabel('Bins')
plt.ylabel('number of pixels')
'''
histB = cv2.calcHist([chans[0]], [0], None, [256], [0, 256])
histG = cv2.calcHist([chans[1]], [0], None, [256], [0, 256])
histR = cv2.calcHist([chans[2]], [0], None, [256], [0, 256])

ax[0].plot(histB, color=colors[0])
ax[1].plot(histG, color=colors[1])
ax[2].plot(histR, color=colors[2])
'''
for (chan, color) in zip(chans, colors):
    hist = cv2.calcHist([chan], [0], None, [256], [0, 256])
    ax.plot(hist, color=color)
'''    
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()
